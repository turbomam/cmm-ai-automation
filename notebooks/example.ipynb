# %% [markdown]
# # CMM AI Automation - Example Notebook
#
# This notebook demonstrates basic usage of the cmm_ai_automation package.

# %%
# Import the package
from pathlib import Path

# %%
# Show project root
project_root = Path.cwd().parent
print(f"Project root: {project_root}")

# %%
# Example: Load data from the data directory
data_dir = project_root / "data"
print(f"Data directory: {data_dir}")
print("\nFiles in data directory:")
for f in sorted(data_dir.glob("*.tsv")):
    print(f"  {f.name}")

# %%
# Add your code here
